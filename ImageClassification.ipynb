# %% [markdown]
# <a href="https://colab.research.google.com/github/togirala/v3/blob/master/ImageClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # !curl -s https://course.fast.ai/setup/colab | bash
# Out:
# Updating fastai...
# Done.

# %%
# Import necessary libraries
from fastai import *
from fastai.vision import * 
import matplotlib.pyplot as plt

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if `dest` doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS)

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
 path_img = path/'images'
 path_anno = path/'annotations'

# %%
fnames = get_image_files(path_img)
np.random.seed(2)
pat = r'/([^/]+)_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %%
data.show_batch(rows = 2)

# %%
data.classes
# Out:
# ['Abyssinian',
#  'Bengal',
#  'Birman',
#  'Bombay',
#  'British_Shorthair',
#  'Egyptian_Mau',
#  'Maine_Coon',
#  'Persian',
#  'Ragdoll',
#  'Russian_Blue',
#  'Siamese',
#  'Sphynx',
#  'american_bulldog',
#  'american_pit_bull_terrier',
#  'basset_hound',
#  'beagle',
#  'boxer',
#  'chihuahua',
#  'english_cocker_spaniel',
#  'english_setter',
#  'german_shorthaired',
#  'great_pyrenees',
#  'havanese',
#  'japanese_chin',
#  'keeshond',
#  'leonberger',
#  'miniature_pinscher',
#  'newfoundland',
#  'pomeranian',
#  'pug',
#  'saint_bernard',
#  'samoyed',
#  'scottish_terrier',
#  'shiba_inu',
#  'staffordshire_bull_terrier',
#  'wheaten_terrier',
#  'yorkshire_terrier']

# %%
# #classes for classification problems
data.c
# Out:
# 37

# %%
learn = cnn_learner(data, models.resnet34, metrics = error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 83.3M/83.3M [00:04<00:00, 19.5MB/s]

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.280806</td>
#       <td>0.298685</td>
#       <td>0.098782</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.338211</td>
#       <td>0.264819</td>
#       <td>0.083221</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.315323</td>
#       <td>0.250872</td>
#       <td>0.069689</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.224461</td>
#       <td>0.229287</td>
#       <td>0.070365</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.182044</td>
#       <td>0.225375</td>
#       <td>0.065629</td>
#       <td>01:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('test-1')

# %%
interprep = ClassificationInterpretation.from_learner(learn)

# %%
interprep.plot_top_losses(9)

# %%
interprep.most_confused(min_val=4)
# Out:
# [('staffordshire_bull_terrier', 'american_pit_bull_terrier', 8),
#  ('basset_hound', 'beagle', 6),
#  ('Egyptian_Mau', 'Bengal', 5),
#  ('Russian_Blue', 'British_Shorthair', 4),
#  ('boxer', 'american_bulldog', 4)]

# %%
learn.unfreeze()
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.649218</td>
#       <td>0.375017</td>
#       <td>0.117050</td>
#       <td>01:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('test-1')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (5912 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# newfoundland,german_shorthaired,samoyed,japanese_chin,miniature_pinscher
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Valid: LabelList (1478 items)
# x: ImageList
# Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224),Image (3, 224, 224)
# y: CategoryList
# staffordshire_bull_terrier,scottish_terrier,yorkshire_terrier,german_shorthaired,chihuahua
# Path: /root/.fastai/data/oxford-iiit-pet/images;
#
# Test: None, model=Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# ...

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.633523</td>
#       <td>0.380754</td>
#       <td>0.117727</td>
#       <td>01:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(2, max_lr = slice(1e-6, 1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.157404</td>
#       <td>0.212643</td>
#       <td>0.066306</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.152104</td>
#       <td>0.216265</td>
#       <td>0.063599</td>
#       <td>01:21</td>
#     </tr>
#   </tbody>
# </table>
